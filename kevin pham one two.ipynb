# %% [markdown]
# Define inital values

# %% [markdown]
# Import math

# %% [markdown]
# Make a loop to calculate two points based on the function

# %%
import math
xa = 1
xb = 3
round_middle = 100
while (round_middle != 0.0):
    left_result = (math.exp(xa)) - 10 + 2*(xa)
    right_result = (math.exp(xb)) - 10 + 2*(xb)
    xm = (xa + xb)/2
    middle_result = (math.exp(xm)) - 10 + 2*(xm)
    round_middle = round(middle_result, 6)
    if middle_result > 0:
        xb = xm
    elif middle_result < 0:
        xa = xm
print(xm)
# Out:
# 1.8428248167037964
# -0.0

# %% [markdown]
# find the intersection of plane 2x + 3y + 4z = 30, using 2 points (1,2,3) and (3,4,5)

# %%
xa = 1
ya = 2
za = 3
xb = 3
yb = 4
zb = 5
xm = 0
ym = 0
zm = 0
round_middle = 100
while (round_middle != 0.0):
    left_result = 2*xa + 3 * ya + 4* za - 30
    right_result = 2*xb + 3 * yb + 4* zb - 30
    xm = (xa + xb)/2
    ym = (ya + yb)/2
    zm = (za + zb)/2
    middle_result = 2*xm + 3 * ym + 4* zm - 30
    round_middle = round(middle_result, 6)
    if middle_result > 0:
        xb = xm
        yb = ym
        zb = zm
    elif middle_result < 0:
        xa = xm
        ya = ym
        za = zm
    print((round(xm, 5), round(ym, 5), round(zm, 5)))
# Out:
# (2.0, 3.0, 4.0)
# (2.5, 3.5, 4.5)
# (2.25, 3.25, 4.25)
# (2.125, 3.125, 4.125)
# (2.0625, 3.0625, 4.0625)
# (2.09375, 3.09375, 4.09375)
# (2.10938, 3.10938, 4.10938)
# (2.11719, 3.11719, 4.11719)
# (2.11328, 3.11328, 4.11328)
# (2.11133, 3.11133, 4.11133)
# (2.11035, 3.11035, 4.11035)
# (2.11084, 3.11084, 4.11084)
# (2.11108, 3.11108, 4.11108)
# (2.11121, 3.11121, 4.11121)
# (2.11115, 3.11115, 4.11115)
# (2.11111, 3.11111, 4.11111)
# (2.1111, 3.1111, 4.1111)
# (2.11111, 3.11111, 4.11111)
# (2.11111, 3.11111, 4.11111)
# (2.11111, 3.11111, 4.11111)
# (2.11111, 3.11111, 4.11111)
# (2.11111, 3.11111, 4.11111)
